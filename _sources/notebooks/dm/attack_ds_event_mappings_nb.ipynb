# %% [markdown]
# # ATT&CK DS Event Mappings Notebook
#
# -----------------------------------

# %% [markdown]
# * **Author**: Jose Luis Rodriguez - [@Cyb3rPandaH](https://twitter.com/Cyb3rPandaH)
# * **Organization**: [Open Threat Research (OTR)](https://github.com/OTRF)
# * **References**:
#  - [OSSEM - ATT&CK Event Mapping](https://github.com/OTRF/OSSEM-DM/blob/main/attack_event_mapping/_attack_data_sources_all.yaml)
#  - [Defining ATT&CK Data Sources, Part I: Enhancing the Current State](https://medium.com/mitre-attack/defining-attack-data-sources-part-i-4c39e581454f)
#  - [Defining ATT&CK Data Sources, Part II: Operationalizing the Methodology](https://medium.com/mitre-attack/defining-attack-data-sources-part-ii-1fc98738ba5b)
#  - [ATT&CK - Data Sources Definition](https://github.com/mitre-attack/attack-datasources/blob/main/DataSourcesDefinition.ipynb)

# %% [markdown]
# ## Importing Python Libraries

# %%
# Importing library to manipulate data
import pandas as pd
from pandas import json_normalize

# Importing library to manipulate yaml data
import yaml
import requests

# %% [markdown]
# ## Importing Data Sources Mapping Yaml File

# %%
yamlUrl = 'https://raw.githubusercontent.com/OTRF/OSSEM-DM/main/attack_event_mapping/_attack_data_sources_all.yaml'
yamlContent = requests.get(yamlUrl)
yamlMapping = yaml.safe_load(yamlContent.text)
mapping = json_normalize(yamlMapping)
mapping.head()
# Out:
#          name                                         definition  \
# 0     Service  Information about software programs that run i...
# 1      Module  Information about portable executable files, s...
# 2  WMI object  Information about objects from the system clas...
# 3        File  Information about file objects that represent ...
# 4  Named pipe  Information about mechanisms that allow inter-...
#
#   collection_layers  platforms                   contributors  \
# 0            [host]  [Windows]  [Jose Rodriguez @Cyb3rPandaH]
# 1            [host]  [Windows]  [Jose Rodriguez @Cyb3rPandaH]
# 2            [host]  [Windows]  [Jose Rodriguez @Cyb3rPandaH]
# 3            [host]  [Windows]  [Jose Rodriguez @Cyb3rPandaH]
# 4            [host]  [Windows]  [Jose Rodriguez @Cyb3rPandaH]
#
#                                      data_components  \
# 0  [{'name': 'service creation', 'type': 'activit...
# 1  [{'name': 'module load', 'type': 'activity', '...
# 2  [{'name': 'wmi object context', 'type': 'infor...
# 3  [{'name': 'file creation', 'type': 'activity',...
# 4  [{'name': 'named pipe creation', 'relationship...
#
#                                           references
# 0  [https://docs.microsoft.com/en-us/dotnet/frame...
# 1  [https://docs.microsoft.com/en-us/windows/win3...
# 2  [https://docs.microsoft.com/en-us/windows/win3...
# 3  [https://docs.microsoft.com/en-us/windows/win3...
# 4  [https://docs.microsoft.com/en-us/windows/win3...

# %% [markdown]
# ## Preparing Data Sources Mapping Dataframe

# %%
# Splitting rows for data_components list
dcListExp = mapping.explode('data_components').reset_index(drop=True).rename(columns={'name':'data_sources'})

# Splitting columns for data_components dict
dcDictExp = dcListExp['data_components'].apply(pd.Series).merge(dcListExp,left_index=True,right_index=True)\
.reset_index(drop=True).rename(columns={'name':'components'}).drop(['data_components'], axis = 1)

# Splitting rows for relationships list
drListExp = dcDictExp.explode('relationships').reset_index(drop=True)

# Splitting columns for relationships dict
drDictExp = drListExp['relationships'].apply(pd.Series).merge(drListExp,left_index=True,right_index=True)\
.reset_index(drop=True).rename(columns={'name':'data_relationships'}).drop(['relationships'], axis = 1)

# Splitting rows for telemetry list
tListExp = drDictExp.explode('telemetry').reset_index(drop=True)

# Splitting columnes for telemetry dict
tDictExp = tListExp['telemetry'].apply(pd.Series).merge(tListExp,left_index=True,right_index=True)\
.reset_index(drop=True).drop(['telemetry'], axis = 1)

# Splitting rows for event_id list
dataSourcesMapping = tDictExp.explode('event_id').reset_index(drop=True)

dataSourcesMapping.head()
# Out:
#                                event_provider event_id  \
# 0         Microsoft-Windows-Security-Auditing     4697
# 1                                      System     7045
# 2        Microsoft-Windows-Sysmon/Operational        7
# 3        Microsoft-Windows-Sysmon/Operational        7
# 4  Microsoft-Windows-WMI-Activity/Operational     5861
#
#           data_relationships                                    id  \
# 0       User created Service  BB243122-F345-4ED6-97A7-FBA2A1AF7C38
# 1       User created Service  BB243122-F345-4ED6-97A7-FBA2A1AF7C38
# 2         Process loaded Dll  109A870F-84A2-4CE4-948A-4773CD283F76
# 3  Process loaded Executable  71F08C96-4ABE-47DE-A972-DEA470496FD4
# 4   Wmi subscription created  F3B6DD23-4DBE-4214-A2D7-10E7103D815F
#
#   source_data_element relationship target_data_element          components  \
# 0                user      created             service    service creation
# 1                user      created             service    service creation
# 2             process       loaded                 dll         module load
# 3             process       loaded          executable         module load
# 4    wmi subscription      created                None  wmi object context
#
#           type data_sources  \
# 0     activity      Service
# 1     activity      Service
# 2     activity       Module
# 3     activity       Module
# 4  information   WMI object
#
#                                           definition collection_layers  \
# 0  Information about software programs that run i...            [host]
# 1  Information about software programs that run i...            [host]
# 2  Information about portable executable files, s...            [host]
# 3  Information about portable executable files, s...            [host]
# 4  Information about objects from the system clas...            [host]
#
#    platforms                   contributors  \
# 0  [Windows]  [Jose Rodriguez @Cyb3rPandaH]
# 1  [Windows]  [Jose Rodriguez @Cyb3rPandaH]
# 2  [Windows]  [Jose Rodriguez @Cyb3rPandaH]
# 3  [Windows]  [Jose Rodriguez @Cyb3rPandaH]
# 4  [Windows]  [Jose Rodriguez @Cyb3rPandaH]
#
#                                           references
# 0  [https://docs.microsoft.com/en-us/dotnet/frame...
# 1  [https://docs.microsoft.com/en-us/dotnet/frame...
# 2  [https://docs.microsoft.com/en-us/windows/win3...
# 3  [https://docs.microsoft.com/en-us/windows/win3...
# 4  [https://docs.microsoft.com/en-us/windows/win3...

# %% [markdown]
# ## Visualizing Relationships Among Data Elements: Network Graph

# %% [markdown]
# * Getting dataframe of relationships among data elements

# %%
relationships = dataSourcesMapping[['source_data_element','target_data_element','relationship']]\
      .drop_duplicates()\
      .dropna().reset_index(drop = True)\
      .rename(columns={'source_data_element':'source','target_data_element':'target'})\
      .replace(['windows registry key','windows registry key value'],['registry key','registry key value'])
relationships.head()
# Out:
#     source        target relationship
# 0     user       service      created
# 1  process           dll       loaded
# 2  process    executable       loaded
# 3     user    wmi filter      created
# 4     user  wmi consumer      created

# %% [markdown]
# * Importing libraries

# %%
import networkx as nx

from bokeh.io import output_notebook, show
from bokeh.models import (BoxSelectTool,LassoSelectTool,PanTool,BoxZoomTool,ResetTool,TapTool,
                          WheelZoomTool,HoverTool,Circle, MultiLine,Plot, Range1d,ColumnDataSource,
                          PointDrawTool,LabelSet,EdgesAndLinkedNodes, NodesAndLinkedEdges,HoverTool)
from bokeh.palettes import Spectral5
from bokeh.plotting import from_networkx

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# * Visualizing network graph

# %%
# Creating networkx graph object
G = nx.from_pandas_edgelist(relationships, source = 'source', target = 'target',edge_attr = 'relationship')

# Creating plot object
plot = Plot(plot_width=800, plot_height=500,
            x_range=Range1d(-1.1, 1.1), y_range=Range1d(-1.1, 1.1))
plot.title.text = "Relationships among Data Elements"
plot.title.align = "center"
plot.title.text_font_size = "30px"

# Creating renderer objects
graph_renderer = from_networkx(G, nx.spring_layout, scale=1, center=(0, 0))

graph_renderer.node_renderer.glyph = Circle(size=60, fill_color=Spectral5[0])
graph_renderer.node_renderer.selection_glyph = Circle(size=15, fill_color=Spectral5[3])
graph_renderer.node_renderer.hover_glyph = Circle(size=15, fill_color=Spectral5[1])

graph_renderer.edge_renderer.glyph = MultiLine(line_color="gray", line_alpha=0.9, line_width=1)
graph_renderer.edge_renderer.selection_glyph = MultiLine(line_color=Spectral5[3], line_width=4)
graph_renderer.edge_renderer.hover_glyph = MultiLine(line_color=Spectral5[1], line_width=4)

graph_renderer.selection_policy = NodesAndLinkedEdges()
graph_renderer.inspection_policy = NodesAndLinkedEdges()
plot.renderers.append(graph_renderer)

# Adding nodes labels
x,y = zip(*graph_renderer.layout_provider.graph_layout.values())

names = []
for i in nx.nodes(G): names.append(i) 
    
nodes_table = ColumnDataSource({'x': x, 'y': y,'name': names})
labels = LabelSet(x='x',y='y',text='name',render_mode='canvas',y_offset=-10,text_align='center',
                  text_font_size='12px',source = nodes_table, background_fill_color=None,text_color = 'black')

plot.renderers.append(labels)

# Adding tools
plot.add_tools(HoverTool(tooltips=None),WheelZoomTool(),TapTool(),BoxSelectTool(),BoxZoomTool(),
               PanTool(),LassoSelectTool(),ResetTool())

# Showing graph
show(plot)
# Out:
#   <div class="bk-root" id="d87686ad-9cce-4743-8023-fb4cc81ea077" data-root-id="1004"></div>

# %% [markdown]
# ## Mapping (sub)techniques to data components & relationships & event logs

# %% [markdown]
# ### Gathering ATT&CK content

# %% [markdown]
# * Importing libraries

# %%
# Importing library to interact with up to date ATT&CK content available in STIX format via public TAXII server
from attackcti import attack_client

# %% [markdown]
# * Gathering (sub)techniques

# %%
# Instantiating attack_client class
lift = attack_client()

# Collecting all techniques (Revoked and not revoked) for windows platform within the enterprise matrix
attck = lift.get_techniques_by_platform(name = 'Windows', stix_format = False)

# Removing revoked techniques
attck = lift.remove_revoked(attck)

# Generating a dataframe with information collected
attck = json_normalize(attck)

# Selecting columns
attck = attck[['tactic','technique_id','technique','data_sources']]

# Showing information collected
attck.head()
# Out:
#                                 tactic technique_id            technique  \
# 0      [credential-access, collection]    T1557.002  ARP Cache Poisoning
# 1  [persistence, privilege-escalation]    T1547.012     Print Processors
# 2                    [defense-evasion]    T1564.007         VBA Stomping
# 3                  [credential-access]    T1558.004      AS-REP Roasting
# 4                    [defense-evasion]    T1218.012             Verclsid
#
#                                         data_sources
# 0          [Packet capture, Netflow/Enclave netflow]
# 1  [Process monitoring, Windows Registry, File mo...
# 2              [Process monitoring, File monitoring]
# 3          [Windows event logs, Authentication logs]
# 4  [Process use of network, Process command-line ...

# %% [markdown]
# * Splitting data_sources field

# %%
attck = attck.explode('data_sources').reset_index(drop=True)
attck.head()
# Out:
#                                 tactic technique_id            technique  \
# 0      [credential-access, collection]    T1557.002  ARP Cache Poisoning
# 1      [credential-access, collection]    T1557.002  ARP Cache Poisoning
# 2  [persistence, privilege-escalation]    T1547.012     Print Processors
# 3  [persistence, privilege-escalation]    T1547.012     Print Processors
# 4  [persistence, privilege-escalation]    T1547.012     Print Processors
#
#               data_sources
# 0           Packet capture
# 1  Netflow/Enclave netflow
# 2       Process monitoring
# 3         Windows Registry
# 4          File monitoring

# %% [markdown]
# * Updating data_sources names

# %%
yamlNamesUrl = 'https://raw.githubusercontent.com/OTRF/OSSEM-DM/main/attack_event_mapping/_new_data_sources_names.yaml'
yamlNamesContent = requests.get(yamlNamesUrl)
names = yaml.safe_load(yamlNamesContent.text)
names = pd.DataFrame(list(names[0].items()), columns=['data_sources', 'new_names'])

attck = pd.merge(attck, names, on = 'data_sources', how = 'left')
namesUpdate = attck['new_names'].fillna(attck['data_sources'])
attck = attck.drop(columns = ['new_names']).assign(data_sources = namesUpdate)
attck = attck.drop_duplicates(subset = ['technique_id','data_sources'])\
        .sort_values(by = ['technique'])\
        .reset_index(drop = True)
attck.head()
# Out:
#                                     tactic technique_id  \
# 0          [credential-access, collection]    T1557.002
# 1          [credential-access, collection]    T1557.002
# 2                      [credential-access]    T1558.004
# 3                      [credential-access]    T1558.004
# 4  [privilege-escalation, defense-evasion]        T1548
#
#                            technique             data_sources
# 0                ARP Cache Poisoning           Packet capture
# 1                ARP Cache Poisoning  Netflow/Enclave netflow
# 2                    AS-REP Roasting       Authentication log
# 3                    AS-REP Roasting       Windows event logs
# 4  Abuse Elevation Control Mechanism                     File

# %% [markdown]
# * Mapping techniques to data components & relationships * event logs

# %%
techniques = pd.merge(attck, dataSourcesMapping, on = 'data_sources', how = 'left')\
             [['tactic','technique_id','technique','data_sources','components','data_relationships',\
               'event_provider','event_id']]

techniques.head()
# Out:
#                             tactic technique_id            technique  \
# 0  [credential-access, collection]    T1557.002  ARP Cache Poisoning
# 1  [credential-access, collection]    T1557.002  ARP Cache Poisoning
# 2              [credential-access]    T1558.004      AS-REP Roasting
# 3              [credential-access]    T1558.004      AS-REP Roasting
# 4              [credential-access]    T1558.004      AS-REP Roasting
#
#               data_sources              components       data_relationships  \
# 0           Packet capture                     NaN                      NaN
# 1  Netflow/Enclave netflow                     NaN                      NaN
# 2       Authentication log  authentication success  User authenticated Host
# 3       Authentication log  authentication success  User authenticated Host
# 4       Windows event logs                     NaN                      NaN
#
#                         event_provider event_id
# 0                                  NaN      NaN
# 1                                  NaN      NaN
# 2  Microsoft-Windows-Security-Auditing     4624
# 3  Microsoft-Windows-Security-Auditing     4778
# 4                                  NaN      NaN

# %% [markdown]
# ### Use Case: SMB/Windows Admin Shares (T1021.002)

# %% [markdown]
# * What are the recommended data sources?

# %%
attck[attck['technique_id']=='T1021.002']
# Out:
#                  tactic technique_id                 technique  \
# 746  [lateral-movement]    T1021.002  SMB/Windows Admin Shares
# 747  [lateral-movement]    T1021.002  SMB/Windows Admin Shares
#
#            data_sources
# 746             Process
# 747  Authentication log

# %% [markdown]
# * What are the potential event logs that we could consider in our analysis?

# %%
techniques[techniques['technique_id']=='T1021.002']
# Out:
#                   tactic technique_id                 technique  \
# 6344  [lateral-movement]    T1021.002  SMB/Windows Admin Shares
# 6345  [lateral-movement]    T1021.002  SMB/Windows Admin Shares
# 6346  [lateral-movement]    T1021.002  SMB/Windows Admin Shares
# 6347  [lateral-movement]    T1021.002  SMB/Windows Admin Shares
# 6348  [lateral-movement]    T1021.002  SMB/Windows Admin Shares
# 6349  [lateral-movement]    T1021.002  SMB/Windows Admin Shares
# 6350  [lateral-movement]    T1021.002  SMB/Windows Admin Shares
# 6351  [lateral-movement]    T1021.002  SMB/Windows Admin Shares
# 6352  [lateral-movement]    T1021.002  SMB/Windows Admin Shares
# 6353  [lateral-movement]    T1021.002  SMB/Windows Admin Shares
# 6354  [lateral-movement]    T1021.002  SMB/Windows Admin Shares
# 6355  [lateral-movement]    T1021.002  SMB/Windows Admin Shares
# 6356  [lateral-movement]    T1021.002  SMB/Windows Admin Shares
# 6357  [lateral-movement]    T1021.002  SMB/Windows Admin Shares
# 6358  [lateral-movement]    T1021.002  SMB/Windows Admin Shares
# 6359  [lateral-movement]    T1021.002  SMB/Windows Admin Shares
# 6360  [lateral-movement]    T1021.002  SMB/Windows Admin Shares
# 6361  [lateral-movement]    T1021.002  SMB/Windows Admin Shares
# 6362  [lateral-movement]    T1021.002  SMB/Windows Admin Shares
# 6363  [lateral-movement]    T1021.002  SMB/Windows Admin Shares
# 6364  [lateral-movement]    T1021.002  SMB/Windows Admin Shares
# 6365  [lateral-movement]    T1021.002  SMB/Windows Admin Shares
# 6366  [lateral-movement]    T1021.002  SMB/Windows Admin Shares
# 6367  [lateral-movement]    T1021.002  SMB/Windows Admin Shares
# 6368  [lateral-movement]    T1021.002  SMB/Windows Admin Shares
# 6369  [lateral-movement]    T1021.002  SMB/Windows Admin Shares
#
#             data_sources                  components  \
# 6344             Process            process creation
# 6345             Process            process creation
# 6346             Process            process creation
# 6347             Process            process creation
# 6348             Process        process modification
# 6349             Process              process access
# 6350             Process              process access
# 6351             Process              process access
# 6352             Process  process network connection
# 6353             Process  process network connection
# 6354             Process  process network connection
# 6355             Process  process network connection
# 6356             Process  process network connection
# 6357             Process  process network connection
# 6358             Process  process network connection
# 6359             Process  process network connection
# 6360             Process  process network connection
# 6361             Process  process network connection
# 6362             Process  process network connection
# 6363             Process  process network connection
# 6364             Process  process network connection
# 6365             Process  process network connection
# 6366             Process  process network connection
# 6367             Process  process network connection
# 6368  Authentication log      authentication success
# 6369  Authentication log      authentication success
#
#                     data_relationships                        event_provider  \
# 6344              User created Process   Microsoft-Windows-Security-Auditing
# 6345              User created Process  Microsoft-Windows-Sysmon/Operational
# 6346           Process created Process   Microsoft-Windows-Security-Auditing
# 6347           Process created Process  Microsoft-Windows-Sysmon/Operational
# 6348          Process wrote to Process  Microsoft-Windows-Sysmon/Operational
# 6349          Process accessed Process   Microsoft-Windows-Security-Auditing
# 6350          Process accessed Process  Microsoft-Windows-Sysmon/Operational
# 6351  Process requested access Process   Microsoft-Windows-Security-Auditing
# 6352         Process connected to Port   Microsoft-Windows-Security-Auditing
# 6353         Process connected to Port  Microsoft-Windows-Sysmon/Operational
# 6354           Process connected to Ip   Microsoft-Windows-Security-Auditing
# 6355           Process connected to Ip  Microsoft-Windows-Sysmon/Operational
# 6356         Process connected to Host  Microsoft-Windows-Sysmon/Operational
# 6357       Process connected from Port   Microsoft-Windows-Security-Auditing
# 6358       Process connected from Port  Microsoft-Windows-Sysmon/Operational
# 6359         Process connected from Ip   Microsoft-Windows-Security-Auditing
# 6360         Process connected from Ip  Microsoft-Windows-Sysmon/Operational
# 6361       Process connected from Host  Microsoft-Windows-Sysmon/Operational
# 6362            User connected to Port  Microsoft-Windows-Sysmon/Operational
# 6363              User connected to Ip  Microsoft-Windows-Sysmon/Operational
# 6364            User connected to Host  Microsoft-Windows-Sysmon/Operational
# 6365          User connected from Port  Microsoft-Windows-Sysmon/Operational
# 6366            User connected from Ip  Microsoft-Windows-Sysmon/Operational
# 6367          User connected from Host  Microsoft-Windows-Sysmon/Operational
# 6368           User authenticated Host   Microsoft-Windows-Security-Auditing
# 6369           User authenticated Host   Microsoft-Windows-Security-Auditing
#
#      event_id
# 6344     4688
# 6345        1
# 6346     4688
# 6347        1
# 6348        8
# 6349     4663
# 6350       10
# 6351     4656
# 6352     5156
# 6353        3
# 6354     5156
# 6355        3
# 6356        3
# 6357     5156
# 6358        3
# 6359     5156
# 6360        3
# 6361        3
# 6362        3
# 6363        3
# 6364        3
# 6365        3
# 6366        3
# 6367        3
# 6368     4624
# 6369     4778

# %% [markdown]
# * **Contribution opportunity identified after testing the framework!!**

# %% [markdown]
# The [Mordor](https://github.com/OTRF/mordor) project contains a dataset that represents a variation of the [SMB/Windows Admin Shares (T1021.002)](https://mordordatasets.com/notebooks/small/windows/08_lateral_movement/SDWIN-200806015757.html) sub-technique.
#
# **Offensive tradecraft:** Adversaries leverage SMB to copy files over the network to either execute code remotely or exfiltrate data.
#
# **Initial detection strategy:** Using the data sources recommended by the ATT&CK team, we were able to get some context related to the adversary behavior from a Procees and User Authentication perspective. However, more context around the manipulation or creation of files might be helpful to define a better detection strategy.
#
# **Contribution opportunity:** Security event logs such as **5140 (A network share object was accessed)** and **5145 (A network share object was checked)** from Windows Security Auditing and **11 (File created)**  from Sysmon can help us with the conext required to define a detection strategy for this specific sub-technqiue variation. Therefore, adding the **File data source object** (file share access & file access data components) to the recommended data sources for this sub-technique might be a good idea.

# %%
dataSourcesMapping[['data_sources','components','data_relationships','event_provider','event_id']][(dataSourcesMapping['data_sources'] == 'File') & \
                   ((dataSourcesMapping['event_id'] == 5140) |\
                    (dataSourcesMapping['event_id'] == 5145) |\
                    (dataSourcesMapping['event_id'] == 11))]
# Out:
#    data_sources         components        data_relationships  \
# 11         File      file creation      Process created File
# 13         File  file share access  User accessed File Share
# 14         File        file access        User accessed File
#
#                           event_provider event_id
# 11  Microsoft-Windows-Sysmon/Operational       11
# 13   Microsoft-Windows-Security-Auditing     5140
# 14   Microsoft-Windows-Security-Auditing     5145

# %% [markdown]
# ## I hope you find this notebook helpful!! :D
