# %% [markdown]
# # Windows Events to ATT&CK Techniques
# * **Author**: Jose Rodriguez (@Cyb3rPandah)
# * **Project**: Infosec Jupyter Book
# * **Public Organization**: [Open Threat Research](https://github.com/OTRF)
# * **License**: [Creative Commons Attribution-ShareAlike 4.0 International](https://creativecommons.org/licenses/by-sa/4.0/)
# * **Reference**: https://github.com/OTRF/OSSEM/tree/master/attack_data_sources

# %% [markdown]
# ### Importing Libraries

# %%
from attackcti import attack_client

import pandas as pd
from pandas import json_normalize
# Do not truncate Pandas output
pd.set_option('display.max_colwidth', None)

import requests

import yaml

# %% [markdown]
# ### Getting ATT&CK enterprise techniques for Windows platform

# %% [markdown]
# * Getting all Windows techniques

# %%
lift = attack_client()
windowsTechniques = lift.get_techniques_by_platform('Windows',stix_format=False)
windowsTechniques = lift.remove_revoked(windowsTechniques)
windowsTechniques = json_normalize(windowsTechniques)
windowsTechniques = windowsTechniques[['tactic','technique_id','technique','data_sources']]
windowsTechniques.head()
# Out:
#                                                  tactic technique_id  \
# 0   [defense-evasion, persistence, command-and-control]    T1205.001
# 1                                     [defense-evasion]    T1564.006
# 2                                     [defense-evasion]    T1564.005
# 3  [persistence, privilege-escalation, defense-evasion]    T1574.012
# 4                                     [defense-evasion]    T1480.001
#
#               technique  \
# 0         Port Knocking
# 1  Run Virtual Instance
# 2    Hidden File System
# 3          COR_PROFILER
# 4  Environmental Keying
#
#                                                                                                                        data_sources
# 0                                                                                         [Netflow/Enclave netflow, Packet capture]
# 1  [Packet capture, Host network interface, Windows Registry, File monitoring, Process monitoring, Process command-line parameters]
# 2                                                                                               [File monitoring, Windows Registry]
# 3                                          [Windows Registry, File monitoring, Process monitoring, Process command-line parameters]
# 4                                                                                                              [Process monitoring]

# %% [markdown]
# * Splitting data_sources

# %%
windowsTechniques = windowsTechniques['data_sources'].apply(pd.Series)\
.merge(windowsTechniques, left_index = True, right_index = True)\
.drop(["data_sources"], axis = 1)\
.melt(id_vars = ['tactic','technique_id','technique'], value_name = "data_sources")\
.drop("variable", axis = 1)\
.dropna(subset=['data_sources'])
windowsTechniques.head()
# Out:
#                                                  tactic technique_id  \
# 0   [defense-evasion, persistence, command-and-control]    T1205.001
# 1                                     [defense-evasion]    T1564.006
# 2                                     [defense-evasion]    T1564.005
# 3  [persistence, privilege-escalation, defense-evasion]    T1574.012
# 4                                     [defense-evasion]    T1480.001
#
#               technique             data_sources
# 0         Port Knocking  Netflow/Enclave netflow
# 1  Run Virtual Instance           Packet capture
# 2    Hidden File System          File monitoring
# 3          COR_PROFILER         Windows Registry
# 4  Environmental Keying       Process monitoring

# %% [markdown]
# ### Getting OSSEM ATT&CK data sources modeling file

# %% [markdown]
# * Getting Yaml File content

# %%
yamlUrl = 'https://raw.githubusercontent.com/OTRF/OSSEM/master/attack_data_sources/event-mappings/all_data_sources.yml'
dataSourcesModelingData = requests.get(yamlUrl)
all_ds = yaml.safe_load(dataSourcesModelingData.text)

# %% [markdown]
# * Creating dictionary of data sources mapped to event IDs

# %%
all_data_sources = {}
# Create DS Keys
for ds_record in all_ds:
    ds_list = ds_record['data_source'].split(", ")
    for ds in ds_list:
        if ds not in all_data_sources.keys():
            all_data_sources[ds] = []
        if ds_record['event_id'] not in all_data_sources[ds]:
            all_data_sources[ds].append(ds_record['event_id'])

# %% [markdown]
# * Generating dataframe

# %%
all_data_sources = pd.DataFrame(list(all_data_sources.items()), columns=['data_sources', 'event_ids'])
all_data_sources
# Out:
#                        data_sources  \
# 0               Authentication logs
# 1                   File monitoring
# 2                    DLL monitoring
# 3            Process use of network
# 4                Windows event logs
# 5                  Windows Registry
# 6                Process monitoring
# 7   Process command-line parameters
# 8                       Loaded DLLs
# 9                       Named Pipes
# 10                      DNS records
#
#                                                                                                                                                                                                                                                                                                                                                                                                                          event_ids
# 0                                                                                                                                                                                                                                                                                                                                                                                                         [4776, 4771, 4624, 4648]
# 1                                                                                                                                                                                                                                                                                                                                                                                [6, 9, 11, 2, 5145, 4656, 4663, 4670, 4660, 4658]
# 2                                                                                                                                                                                                                                                                                                                                                                                                                              [7]
# 3                                                                                                                                                                                                                                                                                                                                                                                    [3, 5031, 5154, 5155, 5156, 5157, 5158, 5159]
# 4   [4768, 4769, 4770, 4773, 4779, 4778, 4800, 4801, 4741, 4742, 4743, 4749, 4750, 4751, 4752, 4753, 4731, 4732, 4733, 4734, 4735, 4764, 4799, 4720, 4722, 4723, 4724, 4725, 4726, 4738, 4740, 4767, 4781, 4798, 4662, 4661, 5136, 5137, 5138, 5139, 5141, 4625, 5140, 5142, 5143, 5144, 4656, 4664, 4698, 4699, 4700, 4701, 4702, 4660, 4663, 4658, 4670, 4657, 4717, 4718, 4674, 4673, 5025, 5034, 4697, 4776, 4771, 4624, 4648]
# 5                                                                                                                                                                                                                                                                                                                                                                                                               [4657, 12, 14, 13]
# 6                                                                                                                                                                                                                                                                                                                                                                                                        [4688, 1, 4689, 5, 8, 10]
# 7                                                                                                                                                                                                                                                                                                                                                                                                                        [4688, 1]
# 8                                                                                                                                                                                                                                                                                                                                                                                                                              [7]
# 9                                                                                                                                                                                                                                                                                                                                                                                                                         [17, 18]
# 10                                                                                                                                                                                                                                                                                                                                                                                                                            [22]

# %% [markdown]
# ### Mapping Techniques to Event Logs

# %% [markdown]
# * Joining **Windows ATT&CK Techniques** & **OSSEM**

# %%
mapping = pd.merge(windowsTechniques, all_data_sources, on = 'data_sources', how = 'left')
mapping.head()
# Out:
#                                                  tactic technique_id  \
# 0   [defense-evasion, persistence, command-and-control]    T1205.001
# 1                                     [defense-evasion]    T1564.006
# 2                                     [defense-evasion]    T1564.005
# 3  [persistence, privilege-escalation, defense-evasion]    T1574.012
# 4                                     [defense-evasion]    T1480.001
#
#               technique             data_sources  \
# 0         Port Knocking  Netflow/Enclave netflow
# 1  Run Virtual Instance           Packet capture
# 2    Hidden File System          File monitoring
# 3          COR_PROFILER         Windows Registry
# 4  Environmental Keying       Process monitoring
#
#                                            event_ids
# 0                                                NaN
# 1                                                NaN
# 2  [6, 9, 11, 2, 5145, 4656, 4663, 4670, 4660, 4658]
# 3                                 [4657, 12, 14, 13]
# 4                          [4688, 1, 4689, 5, 8, 10]

# %% [markdown]
# ### Techniques --> Event IDs

# %% [markdown]
# * T1112 Modify Registry

# %%
T1112 = mapping[mapping['technique_id'] == 'T1112']
T1112
# Out:
#                  tactic technique_id        technique  \
# 304   [defense-evasion]        T1112  Modify Registry
# 653   [defense-evasion]        T1112  Modify Registry
# 945   [defense-evasion]        T1112  Modify Registry
# 1145  [defense-evasion]        T1112  Modify Registry
# 1251  [defense-evasion]        T1112  Modify Registry
#
#                          data_sources  \
# 304                  Windows Registry
# 653                   File monitoring
# 945                Process monitoring
# 1145  Process command-line parameters
# 1251               Windows event logs
#
#                                                                                                                                                                                                                                                                                                                                                                                                                            event_ids
# 304                                                                                                                                                                                                                                                                                                                                                                                                               [4657, 12, 14, 13]
# 653                                                                                                                                                                                                                                                                                                                                                                                [6, 9, 11, 2, 5145, 4656, 4663, 4670, 4660, 4658]
# 945                                                                                                                                                                                                                                                                                                                                                                                                        [4688, 1, 4689, 5, 8, 10]
# 1145                                                                                                                                                                                                                                                                                                                                                                                                                       [4688, 1]
# 1251  [4768, 4769, 4770, 4773, 4779, 4778, 4800, 4801, 4741, 4742, 4743, 4749, 4750, 4751, 4752, 4753, 4731, 4732, 4733, 4734, 4735, 4764, 4799, 4720, 4722, 4723, 4724, 4725, 4726, 4738, 4740, 4767, 4781, 4798, 4662, 4661, 5136, 5137, 5138, 5139, 5141, 4625, 5140, 5142, 5143, 5144, 4656, 4664, 4698, 4699, 4700, 4701, 4702, 4660, 4663, 4658, 4670, 4657, 4717, 4718, 4674, 4673, 5025, 5034, 4697, 4776, 4771, 4624, 4648]

# %% [markdown]
# ### Tactics --> Event IDs

# %% [markdown]
# * Lateral Movement

# %%
lateral_movement = mapping[['data_sources','event_ids']][mapping['tactic'].apply(lambda x: 'lateral-movement' in x)]
lateral_movement = lateral_movement.drop_duplicates(subset='data_sources').reset_index(drop=True)
lateral_movement
# Out:
#                        data_sources  \
# 0   Process command-line parameters
# 1                Process monitoring
# 2            Process use of network
# 3                Windows event logs
# 4               Authentication logs
# 5             Office 365 audit logs
# 6                SSL/TLS inspection
# 7           Windows Error Reporting
# 8                   PowerShell logs
# 9                   File monitoring
# 10                 Windows Registry
# 11          Netflow/Enclave netflow
# 12        Network protocol analysis
# 13                 OAuth audit logs
# 14                      DNS records
# 15                   API monitoring
# 16             Data loss prevention
# 17                   Packet capture
# 18                       Anti-virus
# 19     Third-party application logs
# 20                        Web proxy
# 21                   DLL monitoring
# 22                      Mail server
# 23            Office 365 trace logs
# 24             Binary file metadata
#
#                                                                                                                                                                                                                                                                                                                                                                                                                          event_ids
# 0                                                                                                                                                                                                                                                                                                                                                                                                                        [4688, 1]
# 1                                                                                                                                                                                                                                                                                                                                                                                                        [4688, 1, 4689, 5, 8, 10]
# 2                                                                                                                                                                                                                                                                                                                                                                                    [3, 5031, 5154, 5155, 5156, 5157, 5158, 5159]
# 3   [4768, 4769, 4770, 4773, 4779, 4778, 4800, 4801, 4741, 4742, 4743, 4749, 4750, 4751, 4752, 4753, 4731, 4732, 4733, 4734, 4735, 4764, 4799, 4720, 4722, 4723, 4724, 4725, 4726, 4738, 4740, 4767, 4781, 4798, 4662, 4661, 5136, 5137, 5138, 5139, 5141, 4625, 5140, 5142, 5143, 5144, 4656, 4664, 4698, 4699, 4700, 4701, 4702, 4660, 4663, 4658, 4670, 4657, 4717, 4718, 4674, 4673, 5025, 5034, 4697, 4776, 4771, 4624, 4648]
# 4                                                                                                                                                                                                                                                                                                                                                                                                         [4776, 4771, 4624, 4648]
# 5                                                                                                                                                                                                                                                                                                                                                                                                                              NaN
# 6                                                                                                                                                                                                                                                                                                                                                                                                                              NaN
# 7                                                                                                                                                                                                                                                                                                                                                                                                                              NaN
# 8                                                                                                                                                                                                                                                                                                                                                                                                                              NaN
# 9                                                                                                                                                                                                                                                                                                                                                                                [6, 9, 11, 2, 5145, 4656, 4663, 4670, 4660, 4658]
# 10                                                                                                                                                                                                                                                                                                                                                                                                              [4657, 12, 14, 13]
# 11                                                                                                                                                                                                                                                                                                                                                                                                                             NaN
# 12                                                                                                                                                                                                                                                                                                                                                                                                                             NaN
# 13                                                                                                                                                                                                                                                                                                                                                                                                                             NaN
# 14                                                                                                                                                                                                                                                                                                                                                                                                                            [22]
# 15                                                                                                                                                                                                                                                                                                                                                                                                                             NaN
# 16                                                                                                                                                                                                                                                                                                                                                                                                                             NaN
# 17                                                                                                                                                                                                                                                                                                                                                                                                                             NaN
# 18                                                                                                                                                                                                                                                                                                                                                                                                                             NaN
# 19                                                                                                                                                                                                                                                                                                                                                                                                                             NaN
# 20                                                                                                                                                                                                                                                                                                                                                                                                                             NaN
# 21                                                                                                                                                                                                                                                                                                                                                                                                                             [7]
# 22                                                                                                                                                                                                                                                                                                                                                                                                                             NaN
# 23                                                                                                                                                                                                                                                                                                                                                                                                                             NaN
# 24                                                                                                                                                                                                                                                                                                                                                                                                                             NaN

# %% [markdown]
# ### An opportunity to improve ATT&CK data sources mapping!!

# %% [markdown]
# As we can see in the example above (Lateral Movement techniques), the data source that brings more event logs is **Windows event logs**. However, this data source has a broad scope. We can split this data source in more detailed new data sources.

# %%
lateral_movement[lateral_movement['data_sources'] == 'Windows event logs']
# Out:
#          data_sources  \
# 3  Windows event logs
#
#                                                                                                                                                                                                                                                                                                                                                                                                                         event_ids
# 3  [4768, 4769, 4770, 4773, 4779, 4778, 4800, 4801, 4741, 4742, 4743, 4749, 4750, 4751, 4752, 4753, 4731, 4732, 4733, 4734, 4735, 4764, 4799, 4720, 4722, 4723, 4724, 4725, 4726, 4738, 4740, 4767, 4781, 4798, 4662, 4661, 5136, 5137, 5138, 5139, 5141, 4625, 5140, 5142, 5143, 5144, 4656, 4664, 4698, 4699, 4700, 4701, 4702, 4660, 4663, 4658, 4670, 4657, 4717, 4718, 4674, 4673, 5025, 5034, 4697, 4776, 4771, 4624, 4648]
